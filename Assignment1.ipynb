# %%
import pandas as pd
import numpy as nm

dataset = pd.read_csv('/content/GOOG.csv')

# %%
x= dataset.iloc[:,:-1].values

# %%
dataset.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4858.000000  4858.000000  4858.000000  4858.000000  4858.000000
# mean     41.477174    41.917059    41.055491    41.494404    41.494404
# std      38.590695    39.031758    38.193016    38.618107    38.618107
# min       2.470490     2.534002     2.390042     2.490913     2.490913
# 25%      12.846597    12.954195    12.712414    12.834642    12.834642
# 50%      26.499958    26.728268    26.289323    26.537501    26.537501
# 75%      57.367250    58.028500    56.962251    57.611249    57.611249
# max     151.863495   152.100006   149.887497   150.709000   150.709000
#
#              Volume
# count  4.858000e+03
# mean   1.189152e+08
# std    1.512424e+08
# min    1.584340e+05
# 25%    2.854912e+07
# 50%    6.168836e+07
# 75%    1.467329e+08
# max    1.650833e+09

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4858 entries, 0 to 4857
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4858 non-null   object
#  1   Open       4858 non-null   float64
#  2   High       4858 non-null   float64
#  3   Low        4858 non-null   float64
#  4   Close      4858 non-null   float64
#  5   Adj Close  4858 non-null   float64
#  6   Volume     4858 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 265.8+ KB

# %%
dataset.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
dataset.shape
# Out:
# (4858, 7)

# %%
display(dataset.dtypes.value_counts())
# Out:
# float64    5
# object     1
# int64      1
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_features = dataset.columns[1::]
dataset[numeric_features] = scaler.fit_transform(dataset[numeric_features])
print(dataset.head())
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume
# 0 2004-08-19 -1.010361 -1.007624 -1.012474 -1.009870  -1.009870  5.147976
# 1 2004-08-20 -1.009709 -1.004420 -1.009513 -1.004730  -1.004730  2.247897
# 2 2004-08-23 -1.003422 -1.001612 -1.003937 -1.004027  -1.004027  1.639542
# 3 2004-08-24 -1.003106 -1.002812 -1.007511 -1.006949  -1.006949  1.239734
# 4 2004-08-25 -1.007159 -1.005109 -1.007308 -1.006220  -1.006220  0.434647

# %%
dataset.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.611960  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.640104  184645512

# %%
dataset["Date"] = pd.to_datetime(dataset["Date"])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4858 entries, 0 to 4857
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4858 non-null   datetime64[ns]
#  1   Open       4858 non-null   float64
#  2   High       4858 non-null   float64
#  3   Low        4858 non-null   float64
#  4   Close      4858 non-null   float64
#  5   Adj Close  4858 non-null   float64
#  6   Volume     4858 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 265.8 KB

# %%
dataset.max()
# Out:
# Date         2023-12-05 00:00:00
# Open                    2.860733
# High                    2.823196
# Low                      2.84982
# Close                   2.828358
# Adj Close               2.828358
# Volume                 10.129933
# dtype: object

# %%
dataset
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume
# 0    2004-08-19 -1.010361 -1.007624 -1.012474 -1.009870  -1.009870  5.147976
# 1    2004-08-20 -1.009709 -1.004420 -1.009513 -1.004730  -1.004730  2.247897
# 2    2004-08-23 -1.003422 -1.001612 -1.003937 -1.004027  -1.004027  1.639542
# 3    2004-08-24 -1.003106 -1.002812 -1.007511 -1.006949  -1.006949  1.239734
# 4    2004-08-25 -1.007159 -1.005109 -1.007308 -1.006220  -1.006220  0.434647
# ...         ...       ...       ...       ...       ...        ...       ...
# 4853 2023-11-29  2.526979  2.504704  2.493893  2.457794   2.457794 -0.647375
# 4854 2023-11-30  2.459987  2.435266  2.402113  2.393569   2.393569 -0.588531
# 4855 2023-12-01  2.380167  2.346611  2.385407  2.378031   2.378031 -0.625926
# 4856 2023-12-04  2.327662  2.294085  2.313344  2.308367   2.308367 -0.626861
# 4857 2023-12-05  2.303715  2.347636  2.321986  2.353946   2.353946 -0.659266
#
# [4858 rows x 7 columns]

# %%
dataset.max()
# Out:
# Date         2023-12-05 00:00:00
# Open                    2.860733
# High                    2.823196
# Low                      2.84982
# Close                   2.828358
# Adj Close               2.828358
# Volume                 10.129933
# dtype: object
